# %% [markdown]
# # Week 4 - Lab (Function)

# %% [markdown]
# Q1. Write a function to accept 2 value and find which is the biggest

# %%
def biggestno(a,b):
    if a > b:
        print (f"{a} is the biggest number")
    elif b > a:
        print (f"{b} is the biggest number")
    else:
        print (f"{a} and {b} are equal")
    pass
biggestno(41,14)
biggestno(23,32)
biggestno(50,50)
# Out:
# 41 is the biggest number
# 32 is the biggest number
# 50 and 50 are equal

# %% [markdown]
# Q2. write a function to find the sum of 3 numbers

# %%
def sum_three(n1,n2,n3):
    sum = n1 + n2 + n3
    print(sum)
    pass
sum_three(10,20,39)
# Out:
# 69

# %% [markdown]
# Q 3. Write a function that takes in an arbitrary number of arguments, and returns a list containing only those arguments that are even.

# %%
def even_numbers(*args):
    even_list = []
    for num in args:
        if isinstance(num, (int, float)) and num % 2 == 0:
            even_list.append(num)
    return even_list
print(even_numbers(1, 2, 3, 4, 5, 6))
print(even_numbers(10, 15, 22, 33, 40))
# Out:
# [2, 4, 6]
# [10, 22, 40]

# %% [markdown]
# Q4. write a function to find the sum of n numbers

# %%
def n_num_sum(*args):
    total = 0
    for num in args:
        total += num
    return total
print(n_num_sum(5, 10, 15))
# Out:
# 30

# %% [markdown]
# Q 5.Write a function that takes in a string, and returns a matching string where every even letter is uppercase, and every odd letter is lowercase.

# %%
def alternate_case(text):
    result = ""
    for i, char in enumerate(text):
        if i % 2 == 0:
            result += char.upper()
        else:
            result += char.lower()
    return result
print(alternate_case("muluwerk"))
print(alternate_case("Muluwerk Derebe"))
# Out:
# MuLuWeRk
# MuLuWeRk dErEbE

# %% [markdown]
# Q6. Write a function to return a sentence with the words reversed
#
#     fun_name('I am home') --> 'home am I'
#     fun_name('We are ready') --> 'ready are We'
#
# Note: The .join() method may be useful here. The .join() method allows you to join together strings in a list with some connector string.
#
# This means if you had a list of words you wanted to turn back into a sentence, you could just join them with a single space string:
#
#     >>> " ".join(['Hello','world'])
#     >>> "Hello world"

# %%
def fun_name(sentence):
    words = sentence.split()      #Split sentence into a list of words
    reversed_w = words[::-1]      #Reverse the list
    return " ".join(reversed_w)   #Join back into a sentence
print(fun_name('I am home'))       #'home am I'
print(fun_name('We are ready'))    # 'ready are We'
# Out:
# home am I
# ready are We

# %% [markdown]
# Q7. Write a program to return a string where for every character in the original there are three characters
#
#
#    print_three('Hello') --> 'HHHeeellllllooo'
#
#    print_three('Mississippi') --> 'MMMiiissssssiiippppppiii'

# %%
def print_three(text):
    result = ""
    for char in text:
        return "".join(char * 3 for char in text)
        return result
print(print_three('Hello'))        # HHHeeellllllooo
print(print_three('Mississippi'))  # MMMiiissssssiiippppppiii
# Out:
# HHHeeellllllooo
# MMMiiissssssiiissssssiiippppppiii

# %%
# Check
print_three('HelloWorld')
# Out:
# 'HHH'

# %%
# Check
print_three('Ottawa')
# Out:
# 'OOO'

# %% [markdown]
# Q 8. Write a function to accept three integers between 1 and 9, if their sum is less than or equal to 15, return their sum. If their sum exceeds 15 return 'OMG'

# %%
def too_much(a, b, c):
    if 1<=a and b and c<=9:
        total = a + b + c
    else:
        return  'insert valid number'
    if total <= 15:
        return total
    else:
        return "OMG"
print(too_much(3, 4, 5))   # 12
print(too_much(7, 5, 6))   # OMG
# Out:
# 12
# OMG

# %%
def get_number(num):
    while True:
        n = int(input(num))
        if 1 <= n <= 9:
            return n
        print("Please enter a number from 1 to 9.")
def too_much(a, b, c):
    total = a + b + c
    if total <= 15:
        return total
    else:
        return "OMG"
a = get_number("Enter first number (1–9): ")
b = get_number("Enter second number (1–9): ")
c = get_number("Enter third number (1–9): ")

print(too_much(a, b, c))
# Out:
# Enter first number (1–9):  -1
# Please enter a number from 1 to 9.
# Enter first number (1–9):  9
# Enter second number (1–9):  5
# Enter third number (1–9):  8
# OMG

# %% [markdown]
# ## Great Job!
